# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv("../../evaluation/isolation_forest/netflow/isolation_forest_evaluation.csv")
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("husl")

# %%
df = pd.read_csv("../../evaluation/isolation_forest/netflow/isolation_forest_evaluation.csv")
df

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np



# Crear figura
fig, ax = plt.subplots(figsize=(10, 6))

# Plotear las 3 líneas principales
ax.plot(df['contamination'], df['recall_normal'], 
        marker='o', linewidth=2.5, markersize=7, 
        label='Recall class 0 (Normal)', color='#1f77b4', alpha=0.8)

ax.plot(df['contamination'], df['recall_anomaly'], 
        marker='s', linewidth=2.5, markersize=7, 
        label='Precision class 1 (Anomaly)', color='#ff7f0e', alpha=0.8)

ax.plot(df['contamination'], df['f1_normal'], 
        marker='^', linewidth=2.5, markersize=7, 
        label='F1 class 0 (Normal)', color='#2ca02c', alpha=0.8)

# Formateo del gráfico
ax.set_xlabel('Contamination', fontsize=12, fontweight='bold')
ax.set_ylabel('Metric value', fontsize=12, fontweight='bold')
ax.set_title('Isolation Forest: metrics vs contamination (class 0)', 
             fontsize=13, fontweight='bold')
ax.legend(fontsize=10, loc='upper left')
ax.grid(True, alpha=0.3)
ax.set_ylim([0.3, 1.05])
ax.set_xlim([0, 0.55])

# Estilo similar a la imagen
plt.tight_layout()
plt.savefig('isolation_forest_metrics.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Graph saved: isolation_forest_metrics.png")
# Out:
# ✓ Graph saved: isolation_forest_metrics.png

# %%
# Out:
# ...
# 📊 KEY METRICS AT OPTIMAL CONFIGURATION
# ...
#   Contamination                  0.45
#   F1 Anomaly Score               0.4915 ← BEST
#   Recall Anomaly                 0.9899 (99.0% detection rate)
#   Precision Anomaly              0.3269 (32.7% are true positives)
#   Recall Normal                  0.5500 (55.0% preserved)
#   Precision Normal               0.9960
#   Accuracy                       0.6296
#   ---                            ---
#   True Positives (TP)            163,244
#   False Positives (FP)           336,130
#   False Negatives (FN)           1,670
#   True Negatives (TN)            410,870
# ...

# %%
# Out:
# ✓ Graph saved
