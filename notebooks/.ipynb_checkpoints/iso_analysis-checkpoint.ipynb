# %%
import pandas as pd

df = pd.read_csv('isolation_forest_evaluation.csv')
iso
# Out:
#     contamination  n_estimators  random_state  elapsed_sec  accuracy  \
# 0            0.01           100            42        11.43    0.8111
# 1            0.02           100            42        10.75    0.8030
# 2            0.03           100            42        10.78    0.7949
# 3            0.04           100            42        10.66    0.7870
# 4            0.05           100            42        11.06    0.7788
# 5            0.10           100            42        11.25    0.7393
# 6            0.15           100            42        11.40    0.7033
# 7            0.20           100            42        10.96    0.6622
# 8            0.30           100            42        12.31    0.6272
# 9            0.40           100            42        11.99    0.6502
# 10           0.45           100            42        11.42    0.6296
# 11           0.50           100            42        11.03    0.5890
#
#     precision_normal  recall_normal  f1_normal  support_normal  \
# ...

# %%
iso["precision_normal"]
# Out:
# 0     0.8177
# 1     0.8163
# 2     0.8149
# 3     0.8135
# 4     0.8120
# 5     0.8049
# 6     0.8001
# 7     0.7904
# 8     0.8191
# 9     0.9568
# 10    0.9960
# 11    0.9969
# Name: precision_normal, dtype: float64
